# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
import os

print("CURRENT DIRECTORY:")
print(os.getcwd())

print("\nProcessed folder:")
print(os.path.exists("../../datasets/processed"))

if os.path.exists("../../datasets/processed"):
    print(os.listdir("../../datasets/processed"))
# Out:
# CURRENT DIRECTORY:
# c:\Users\abc\Dividend-Puzzle-Analyzer\notebooks
#
# Processed folder:
# False

# %%
from pathlib import Path

print("Current directory:")
print(Path.cwd())

print("\nSearching for ml_dataset.csv...")

files = list(Path.cwd().parent.parent.rglob("ml_dataset.csv"))

for file in files:
    print(file)
# Out:
# Current directory:
# c:\Users\abc\Dividend-Puzzle-Analyzer\notebooks
#
# Searching for ml_dataset.csv...
# c:\Users\abc\Dividend-Puzzle-Analyzer\datasets\processed\ml_dataset.csv

# %%
import pandas as pd
import numpy as np

data = pd.read_csv(
    "../datasets/processed/ml_dataset.csv"
)

print("ML dataset loaded successfully!")
print("Shape:", data.shape)
print(data.head())
# Out:
# ML dataset loaded successfully!
# Shape: (100, 5)
#    dividend_yield  dividend_growth  dividend_consistency  return_volatility  \
# 0            1.93             9.85                 90.91              36.16
# 1            1.45            10.31                 90.91              36.16
# 2            1.79            14.63                 90.91              36.16
# 3            1.04             7.80                 90.91              36.16
# 4            0.61             6.25                 90.91              36.16
#
#    total_return
# 0         11.96
# 1         47.56
# 2         -5.00
# 3         87.20
# 4         81.36

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = data[
    [
        "dividend_yield",
        "dividend_growth",
        "dividend_consistency",
        "return_volatility"
    ]
]

y = data["total_return"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (100, 4)
# y shape: (100,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (80, 4)
# X_test shape: (20, 4)
# y_train shape: (80,)
# y_test shape: (20,)

# %%
model = LinearRegression()

model.fit(X_train, y_train)

print("Linear Regression model trained successfully!")
# Out:
# Linear Regression model trained successfully!

# %%
y_pred = model.predict(X_test)

print("First 10 predictions:")
print(y_pred[:10])
# Out:
# First 10 predictions:
# [22.98101664  9.72294162  4.02004682 24.23448042 22.48668094 12.68658621
#   5.34074072 17.07840384 11.16336897 22.15869402]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Linear Regression Results")
print("-------------------------")
print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R²  :", r2)
# Out:
# Linear Regression Results
# -------------------------
# MAE : 12.896688748879361
# MSE : 303.6465688580839
# RMSE: 17.425457493508855
# R²  : 0.3665095339776454

# %%
coefficients = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_
})

print(coefficients)
# Out:
#                 Feature   Coefficient
# 0        dividend_yield -5.239004e+00
# 1       dividend_growth -7.276577e-01
# 2  dividend_consistency -1.253911e-31
# 3     return_volatility  4.507746e-01

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Linear Regression Results")
print("-------------------------")
print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
print("R²  :", r2)
# Out:
# Linear Regression Results
# -------------------------
# MAE : 12.896688748879361
# MSE : 303.6465688580839
# RMSE: 17.425457493508855
# R²  : 0.3665095339776454

# %%
results = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})

results.to_csv(
    "../datasets/processed/day17_linear_regression_results.csv",
    index=False
)

print("Day 17 results saved successfully!")
# Out:
# Day 17 results saved successfully!

# %%
import os

print(
    os.path.exists(
        "../datasets/processed/day17_linear_regression_results.csv"
    )
)
# Out:
# True
